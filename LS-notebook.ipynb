# %% [markdown]
# # Install iRuby

# %% [markdown]
# Run below code to install iRuby

# %%
!apt-get install ruby-dev
!sudo apt install libtool libffi-dev ruby ruby-dev make
!sudo apt install libzmq3-dev libczmq-dev
!gem install cztop
!gem install specific_install
!gem specific_install https://github.com/SciRuby/iruby
!iruby register
!jupyter kernelspec install ~/.ipython/kernels/ruby

# %% [markdown]
# Change Runtime type and run below code to confirm ruby is working correctly

# %%
puts "hello world, Ruby works"
# Out:
# hello world, Ruby works

# %% [markdown]
# # New Section

# %%
first_name = "Jameson"
last_name = "Wilder"

puts first_name + " " + last_name

puts "#{first_name} #{last_name}"

puts "Jameson " + "Wilder"
